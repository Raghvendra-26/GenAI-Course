# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model = "gemma3:4b")

# %%
res = llm.invoke("Hello, I am Raghvendra")
print(res.content)
# Out:
# Hello Raghvendra! It’s nice to meet you. 😊
#
# How are you doing today? Is there anything you’d like to chat about, or were you just saying hello?

# %%
res = llm.invoke("Your knowledge cutoff date")
print(res.content)
# Out:
# My knowledge cutoff date is **September 2021**.
#
# This means I don't have information about events, discoveries, or changes that happened *after* that date.
#
# While I can still access and process information up to September 2021, it's important to keep that limitation in mind when we're discussing current events or very recent developments.
