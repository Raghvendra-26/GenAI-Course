# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model="llama3.2:3b",
    temperature=0.7
)

# %%
prompts = [
    {"role":"system","content":"You are a javascript developer"},
    {"role":"user","content":"Difference between map and filter"}
]

res = llm.invoke(prompts)

# %%
print(res.content)
# Out:
# `map()` and `filter()` are two of the most commonly used array methods in JavaScript. While they're often confused with each other, they serve distinct purposes.
#
# **`Array.prototype.filter()`**
#
# The `filter()` method creates a new array with all elements that pass the test implemented by the provided function. It returns a new array with only the elements that satisfy the condition.
#
#  Syntax: `arr.filter(callback(index, value), thisArg)`
#
# Example:
# ```javascript
# const numbers = [1, 2, 3, 4, 5];
#
# // Filter out even numbers
# const oddNumbers = numbers.filter((num) => num % 2 !== 0);
# console.log(oddNumbers); // Output: [1, 3, 5]
# ```
# In this example, the `filter()` method creates a new array with only the odd numbers from the original array.
#
# **`Array.prototype.map()`**
#
# The `map()` method creates a new array populated with the results of calling a provided function on every element in the calling array.
#
#  Syntax: `arr.map(callback(index, value), thisArg)`
#
# Example:
# ```javascript
# const numbers = [1, 2, 3, 4, 5];
#
# // Square each number
# const squaredNumbers = numbers.map((num) => num ** 2);
# console.log(squaredNumbers); // Output: [1, 4, 9, 16, 25]
# ```
# In this example, the `map()` method creates a new array with the squares of each number from the original array.
#
# **Key differences**
#
# 1. **Purpose**: `filter()` removes elements that don't meet a condition, while `map()` transforms elements into something new.
# 2. **Return value**: `filter()` returns a new array with filtered elements, while `map()` returns a new array with transformed elements.
# 3. **Order**: The order of elements in the original array is preserved in `filter()`, but it's reversed in `map()`.
#
# To summarize:
#
# * Use `filter()` when you want to remove unwanted elements from an array.
# * Use `map()` when you want to transform or process each element in an array.
#
# Hope this helps clarify the difference between `map()` and `filter()`!

# %%
prompts = [
    {"role":"system","content":"You are a python developer"},
    {"role":"user","content":"Difference between map and filter"}
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# **Map vs Filter in Python**
# =====================================
#
# In Python, `map()` and `filter()` are two built-in functions that can be used to process data. While they share some similarities, they serve different purposes and have distinct behaviors.
#
# **Map()**
# --------
#
# `map()` applies a given function to each item of an iterable (such as a list or tuple) and returns a new iterator with the results.
#
# **Example:**
# ```python
# def double(x):
#     return x * 2
#
# numbers = [1, 2, 3, 4, 5]
# doubled_numbers = map(double, numbers)
# print(list(doubled_numbers))  # Output: [2, 4, 6, 8, 10]
# ```
# In this example, the `double` function is applied to each number in the `numbers` list.
#
# **Filter()**
# ---------
#
# `filter()` constructs an iterator from elements of an iterable for which a function returns True.
#
# **Example:**
# ```python
# def is_even(x):
#     return x % 2 == 0
#
# numbers = [1, 2, 3, 4, 5]
# even_numbers = filter(is_even, numbers)
# print(list(even_numbers))  # Output: [2, 4]
# ```
# In this example, the `is_even` function is applied to each number in the `numbers` list.
#
# **Key differences:**
#
# *   **Transformation vs Selection**: `map()` transforms data by applying a function to each item, while `filter()` selects items based on a predicate.
# *   **Return value**: Both functions return iterators, but `map()` returns an iterator that yields transformed values, whereas `filter()` returns an iterator that yields selected values.
# *   **Side effects**: `map()` can have side effects if the function being mapped has mutable state or modifies external variables. `filter()` typically does not have this issue since it doesn't modify external data.
#
# **Choosing between Map and Filter**
# ----------------------------------
#
# Use `map()` when:
#
# *   You need to perform a transformation on each item in an iterable.
# *   The transformation is simple and can be expressed as a function.
#
# Use `filter()` when:
#
# *   You need to select items from an iterable based on a condition.
# *   You want to avoid modifying external data.
#
# **Best practices:**
#
# *   Prefer `map()` over `filter()` for simple transformations, especially when the transformation involves only basic operations like arithmetic or string manipulation.
# *   Use `filter()` for more complex selection criteria, such as checking multiple conditions or using a lambda function with a predicate.

# %% [markdown]
# #### Prompts Templates - Dynamic Prompts

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOllama(
    model="llama3.2:3b",
    temperature=0.7
)
out = StrOutputParser()

# %%
def transform_case(result : str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system","content":"You are a translator and translate input in {language}"},
    {"role":"user","content":"{query}"}
])

# %%
# final_prompt = prompts.format_messages(language = "Hindi", query = "I love to play cricket")

# res = llm.invoke(final_prompt)
# print(res.content)
# Out:
# मैं क्रिकेट खेलने में बहुत आनंद लेता हूँ। (Main krrickt khelne mein bahut anand lete hain)
#
# OR
# मुझे क्रिकेट बहुत पसंद है। (Mujhe krrict bht pasand hai)
#
# OR
# मैं क्रिकेट खेलना में रुचि रखता हूँ। (Main krrickt khelne mein ruchit rahta hoon)

# %% [markdown]
# #### Chains - Runnable

# %%
# res = llm.invoke(prompts.invoke({"language":"Hindi","query":"I love you"}))

# print(res.content)
# Out:
# मैं तुम्हारा प्यार करता हूँ (Main tumhare pyar karta hoon)

# %%
chains = prompts | llm | out | transform_case

# %%
res = chains.invoke({"language":"English","query":"Which city is known as Pink city?"})
print(res)
# Out:
# JAIPUR IS KNOWN AS THE "PINK CITY".
