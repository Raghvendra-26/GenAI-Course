# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
# google search
search.run("Who won Super Copa De Espana 2026")
# Out:
# 'The King Abdullah Sports City in Jeddah hosted the final. Barcelona won the match 3–2 for their 16th Supercopa de España title. Barcelona won the tournament for their record-extending sixteenth Supercopa de España title. FC Barcelona have taken their second Spanish Super Cup title in a row in Jeddah, Saudi Arabia after a 3-2 win over Real Madrid in the final. ... a deflected shot from Raphinha edged Barcelona ahead for the third time in the match. Barcelona were later reduced to ten men when Frenkie de ... Raphinha scored twice in Saudi Arabia as Barcelona beat Real Madrid 3-2 on Sunday in the final of the Spanish Super Cup. Jan 11, 2026, 01:29 pm ... Madrid were beaten in the final of the Spanish Super Cup held in Jeddah. The first half hour of the Clásico was very evenly matched, ... BARCELONA DOMINATE REAL MADRID TO CLINCH FIFTH SUPER CUP! ⚽ Barcelona delivered a stunning performance, defeating Real Madrid 4-1 in the ... 🚨 𝐎𝐅𝐅𝐈𝐂𝐈𝐀𝐋: 𝐁𝐀𝐑𝐂𝐄𝐋𝐎𝐍𝐀 𝐖𝐈𝐍 𝐓𝐇𝐄 𝐒𝐏𝐀𝐍𝐈𝐒𝐇 𝐒𝐔𝐏𝐄𝐑 𝐂𝐔𝐏 𝐀𝐆𝐀𝐈𝐍 🏆 All-time Supercopa de España winners: 16 🏆 | Barcelona. 13 🏆 | Real Madrid. The first trophy of 2026. FC Barcelona have taken their second Spanish Super Cup title in a row in Jeddah, Saudi Arabia after a 3-2 win over ... Raphinha scored twice as Barcelona beat Real Madrid 3-2 in the Spanish Super Cup final in Jeddah.'

# %%
agent = create_agent(
    model = llm,
    tools = [search.run],
    system_prompt="You are an agent and can search any question on google."
)

# %%
question = "Is capf 2026 application started?"

# %%
response = agent.invoke({"messages":[{"role":"user","content":question}]})

# %%
print(response['messages'][-1].content)
# Out:
# **Yes – the CAPF 2026 application window is already open.**
#
# | Item | Details |
# |------|---------|
# | **Notification Release** | 20 February 2026 (official UPSC website) |
# | **Online Application Start** | 20 February 2026, 6:00 PM (Indian Standard Time) |
# | **Last Date for Application & Fee Payment** | 12 March 2026, 6:00 PM |
# | **Exam Date** | 19 July 2026 |
# | **How to Apply** | 1. Visit the UPSC portal: <https://upsconline.nic.in> <br> 2. Register and log in. <br> 3. Fill the CAPF Assistant Commandant (Group A) application form. <br> 4. Pay the application fee online. <br> 5. Upload required documents (photograph, signature, etc.). |
# | **Important Points** | • Only graduates (or equivalent) who meet the eligibility criteria can apply. <br> • Keep the application receipt; you’ll need it for the preliminary exam. <br> • Check the UPSC website for any updates or changes. |
#
# **Bottom line:** If you’re eligible and ready, you can submit your application now—just make sure to complete it before the 12 March deadline.
